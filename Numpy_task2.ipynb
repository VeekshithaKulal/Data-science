# %% [markdown]
# <a href="https://colab.research.google.com/github/VeekshithaKulal/Data-science/blob/main/Numpy_task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# Generate an array of 5 random integers between 10 and 50
np.random.randint(10,50,5)
# Out:
# array([45, 39, 22, 30, 48])

# %%
#  Generate a 2×3 matrix of random values between 0 and 1
np.random.rand(2,3)
# Out:
# array([[0.1170673 , 0.47177527, 0.66414929],
#        [0.29156084, 0.63638741, 0.30983878]])

# %%
# Combine these two arrays into one:
a=np.array([1,2,3])
b=np.array([4,5,6])
np.concatenate([a,b])
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
# From this array:arr = np.array([3, 7, 2, 7, 9, 2, 3])
# Find the unique values.
arr = np.array([3, 7, 2, 7, 9, 2, 3])
np.unique([arr])
# Out:
# array([2, 3, 7, 9])

# %%
# Using this matrix:Calculate its transpose.

A = np.array([[1, 2],[3, 4]])
np.transpose([A])
# Out:
# array([[[1],
#         [3]],
#
#        [[2],
#         [4]]])

# %%
# Perform matrix multiplication:
A = np.array([[1, 2],
              [3, 4]])
B = np.array([[5, 6],
              [7, 8]])
np.dot(A,B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
# Find the indices where elements of this array are greater than 50:
arr = np.array([12, 67, 45, 89, 23])
np.where(arr>50)
# Out:
# (array([1, 3]),)
